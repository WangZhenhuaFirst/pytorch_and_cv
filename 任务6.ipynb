# %% [markdown]
# ## 任务6：PyTorch常见的损失函数和优化器使用
# 参考：https://zhuanlan.zhihu.com/p/86982616

# %%
# 学习率0.1,结果损失函数为nan
import numpy as np
import torch
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader


x_train = np.arange(0, 100, 0.01, dtype=np.float32)
x_train = x_train.reshape(x_train.shape[0], 1)
y_train = 10 * x_train + 4 + np.random.randn()
x_train = torch.from_numpy(x_train)
y_train = torch.from_numpy(y_train)
dataset = TensorDataset(x_train, y_train) 
batch_size = 100
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)


class LinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)
    
    def forward(self, x):
        out = self.linear(x)
        return out 
    
epochs = 500
learning_rate = 0.1
loss_func = torch.nn.MSELoss()
model = LinearRegression()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

for i in range(epochs):
    for inp, target in train_loader:
        prediction = model(inp)
        loss = loss_func(prediction, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if i % 20 == 0:
        print(loss)
# Out:
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)

# %%
# 学习率0.5,结果损失函数为nan
import numpy as np
import torch
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader


x_train = np.arange(0, 100, 0.01, dtype=np.float32)
x_train = x_train.reshape(x_train.shape[0], 1)
y_train = 10 * x_train + 4 + np.random.randn()
x_train = torch.from_numpy(x_train)
y_train = torch.from_numpy(y_train)
dataset = TensorDataset(x_train, y_train) 
batch_size = 100
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)


class LinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)
    
    def forward(self, x):
        out = self.linear(x)
        return out 
    
epochs = 500
learning_rate = 0.5
loss_func = torch.nn.MSELoss()
model = LinearRegression()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

for i in range(epochs):
    for inp, target in train_loader:
        prediction = model(inp)
        loss = loss_func(prediction, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if i % 40 == 0:
        print(loss)
# Out:
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)

# %%
# 学习率0.01,结果损失函数为nan
import numpy as np
import torch
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader


x_train = np.arange(0, 100, 0.01, dtype=np.float32)
x_train = x_train.reshape(x_train.shape[0], 1)
y_train = 10 * x_train + 4 + np.random.randn()
x_train = torch.from_numpy(x_train)
y_train = torch.from_numpy(y_train)
dataset = TensorDataset(x_train, y_train) 
batch_size = 100
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)


class LinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)
    
    def forward(self, x):
        out = self.linear(x)
        return out 
    
epochs = 500
learning_rate = 0.01
loss_func = torch.nn.MSELoss()
model = LinearRegression()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

for i in range(epochs):
    for inp, target in train_loader:
        prediction = model(inp)
        loss = loss_func(prediction, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if i % 50 == 0:
        print(loss)
# Out:
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)
# tensor(nan, grad_fn=<MseLossBackward>)

# %%
# 学习率采用 1e-4,结果正常
import numpy as np
import torch
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader


x_train = np.arange(0, 100, 0.01, dtype=np.float32)
x_train = x_train.reshape(x_train.shape[0], 1)
y_train = 10 * x_train + 4 + np.random.randn()
x_train = torch.from_numpy(x_train)
y_train = torch.from_numpy(y_train)
dataset = TensorDataset(x_train, y_train) 
batch_size = 100
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)


class LinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)
    
    def forward(self, x):
        out = self.linear(x)
        return out 
    
epochs = 500
learning_rate = 1e-4
loss_func = torch.nn.MSELoss()
model = LinearRegression()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

for i in range(epochs):
    for inp, target in train_loader:
        prediction = model(inp)
        loss = loss_func(prediction, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if i % 10 == 0:
        print(loss)
# Out:
# tensor(5.1777, grad_fn=<MseLossBackward>)
# tensor(4.3616, grad_fn=<MseLossBackward>)
# tensor(4.0512, grad_fn=<MseLossBackward>)
# tensor(3.8147, grad_fn=<MseLossBackward>)
# tensor(2.6733, grad_fn=<MseLossBackward>)
# tensor(3.5861, grad_fn=<MseLossBackward>)
# tensor(2.9015, grad_fn=<MseLossBackward>)
# tensor(1.8799, grad_fn=<MseLossBackward>)
# tensor(1.9884, grad_fn=<MseLossBackward>)
# tensor(2.0097, grad_fn=<MseLossBackward>)
# tensor(1.6599, grad_fn=<MseLossBackward>)
# tensor(1.6534, grad_fn=<MseLossBackward>)
# tensor(1.5633, grad_fn=<MseLossBackward>)
# tensor(1.2140, grad_fn=<MseLossBackward>)
# tensor(1.1816, grad_fn=<MseLossBackward>)
# tensor(1.2649, grad_fn=<MseLossBackward>)
# tensor(0.8961, grad_fn=<MseLossBackward>)
# tensor(0.8244, grad_fn=<MseLossBackward>)
# tensor(0.7206, grad_fn=<MseLossBackward>)
# tensor(0.7845, grad_fn=<MseLossBackward>)
# tensor(0.6652, grad_fn=<MseLossBackward>)
# tensor(0.5506, grad_fn=<MseLossBackward>)
# tensor(0.5911, grad_fn=<MseLossBackward>)
# tensor(0.4300, grad_fn=<MseLossBackward>)
# tensor(0.4275, grad_fn=<MseLossBackward>)
# tensor(0.3878, grad_fn=<MseLossBackward>)
# tensor(0.4043, grad_fn=<MseLossBackward>)
# tensor(0.3104, grad_fn=<MseLossBackward>)
# tensor(0.3054, grad_fn=<MseLossBackward>)
# tensor(0.2401, grad_fn=<MseLossBackward>)
# tensor(0.2842, grad_fn=<MseLossBackward>)
# tensor(0.2343, grad_fn=<MseLossBackward>)
# tensor(0.1808, grad_fn=<MseLossBackward>)
# tensor(0.2105, grad_fn=<MseLossBackward>)
# tensor(0.1606, grad_fn=<MseLossBackward>)
# tensor(0.1465, grad_fn=<MseLossBackward>)
# tensor(0.1316, grad_fn=<MseLossBackward>)
# tensor(0.1268, grad_fn=<MseLossBackward>)
# tensor(0.1036, grad_fn=<MseLossBackward>)
# tensor(0.1161, grad_fn=<MseLossBackward>)
# tensor(0.0918, grad_fn=<MseLossBackward>)
# tensor(0.0959, grad_fn=<MseLossBackward>)
# tensor(0.0711, grad_fn=<MseLossBackward>)
# tensor(0.0674, grad_fn=<MseLossBackward>)
# tensor(0.0641, grad_fn=<MseLossBackward>)
# tensor(0.0469, grad_fn=<MseLossBackward>)
# tensor(0.0485, grad_fn=<MseLossBackward>)
# tensor(0.0385, grad_fn=<MseLossBackward>)
# tensor(0.0492, grad_fn=<MseLossBackward>)
# tensor(0.0352, grad_fn=<MseLossBackward>)
